# %% [markdown]
# # Resimulation analysis

# %%
# Importing external packages

import os
import sys
import matplotlib.pyplot as plt
from matplotlib.patches import Patch
from matplotlib.lines import Line2D
import matplotlib as mpl
import math
import seaborn as sns
import pandas as pd
import numpy as np
import statistics
from collections import defaultdict
from tqdm import tqdm
from pandas.plotting import parallel_coordinates
from matplotlib.lines import Line2D
from ema_workbench.analysis import feature_scoring
from ema_workbench.analysis import dimensional_stacking
import importlib
import warnings

warnings.filterwarnings(action="once")
# Out:
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/ema_workbench/analysis/prim.py:30: ImportWarning: altair based interactive inspection not available
#   warnings.warn(("altair based interactive "

# %%
# Importing model scripts, by first adding the main folder path

module_path = os.path.abspath(os.path.join(".."))
if module_path not in sys.path:
    sys.path.append(module_path)

from model.model_nile import ModelNile
from experimentation.data_generation import generate_input_data
import plotter

import matplotlib
import matplotlib.font_manager as fm

# sns.set(font_scale=1.2)

fm.fontManager.addfont("Minion Pro Regular.ttf")
matplotlib.rc("font", family="Minion Pro")

from matplotlib import rcParams

rcParams["font.family"] = "Minion Pro"
rcParams["font.sans-serif"] = "Minion Pro"
rcParams["font.size"] = 16

# %% [markdown]
# Read the results of the open exploration:

# %%
experiments = pd.read_csv("../outputs/experiments_resimulation.csv").drop(
    columns="Unnamed: 0"
)
outcomes = pd.read_csv("../outputs/outcomes_resimulation.csv").drop(
    columns="Unnamed: 0"
)

# %%
experiments.head(15)
# Out:
#     yearly_demand_growth_rate  blue_nile_mean_coef  white_nile_mean_coef  \
# 0                      0.0212                 1.00                  1.00
# 1                      0.0300                 0.75                  0.75
# 2                      0.0300                 0.75                  1.25
# 3                      0.0100                 1.00                  1.00
# 4                      0.0212                 1.25                  1.00
# 5                      0.0212                 1.00                  1.00
# 6                      0.0300                 0.75                  0.75
# 7                      0.0300                 0.75                  1.25
# 8                      0.0100                 1.00                  1.00
# 9                      0.0212                 1.25                  1.00
# 10                     0.0212                 1.00                  1.00
# 11                     0.0300                 0.75                  0.75
# 12                     0.0300                 0.75                  1.25
# 13                     0.0100                 1.00                  1.00
# 14                     0.0212                 1.25                  1.00
#
#     atbara_mean_coef  blue_nile_dev_coef  white_nile_dev_coef  \
# 0               1.00                 1.0                  1.0
# 1               0.75                 1.0                  1.0
# 2               1.25                 1.0                  1.0
# 3               1.00                 1.0                  1.0
# 4               1.00                 1.0                  1.0
# 5               1.00                 1.0                  1.0
# 6               0.75                 1.0                  1.0
# 7               1.25                 1.0                  1.0
# 8               1.00                 1.0                  1.0
# 9               1.00                 1.0                  1.0
# 10              1.00                 1.0                  1.0
# 11              0.75                 1.0                  1.0
# 12              1.25                 1.0                  1.0
# 13              1.00                 1.0                  1.0
# 14              1.00                 1.0                  1.0
#
#     atbara_dev_coef        v0        v1        v2  ...      v157      v158  \
# 0               1.0  0.005230  0.087435  0.580001  ...  0.534270 -0.553612
# 1               1.0  0.005230  0.087435  0.580001  ...  0.534270 -0.553612
# 2               1.0  0.005230  0.087435  0.580001  ...  0.534270 -0.553612
# 3               1.0  0.005230  0.087435  0.580001  ...  0.534270 -0.553612
# 4               1.0  0.005230  0.087435  0.580001  ...  0.534270 -0.553612
# 5               1.0  0.005551  0.114852  0.416813  ...  0.538180  0.926470
# 6               1.0  0.005551  0.114852  0.416813  ...  0.538180  0.926470
# 7               1.0  0.005551  0.114852  0.416813  ...  0.538180  0.926470
# 8               1.0  0.005551  0.114852  0.416813  ...  0.538180  0.926470
# 9               1.0  0.005551  0.114852  0.416813  ...  0.538180  0.926470
# 10              1.0  0.030241  0.398095  0.573043  ...  0.537434  0.924409
# 11              1.0  0.030241  0.398095  0.573043  ...  0.537434  0.924409
# 12              1.0  0.030241  0.398095  0.573043  ...  0.537434  0.924409
# 13              1.0  0.030241  0.398095  0.573043  ...  0.537434  0.924409
# 14              1.0  0.030241  0.398095  0.573043  ...  0.537434  0.924409
#
#         v159      v160      v161      v162      v163           scenario  \
# 0   0.148301  0.390411  0.315424  0.513462  0.395253           Baseline
# 1   0.148301  0.390411  0.315424  0.513462  0.395253      ExtremeStress
# 2   0.148301  0.390411  0.315424  0.513462  0.395253  CompensatedStress
# 3   0.148301  0.390411  0.315424  0.513462  0.395253          LowDemand
# 4   0.148301  0.390411  0.315424  0.513462  0.395253       HighBlueNile
# 5   0.776713  0.359905  0.096117  0.706763  0.365144           Baseline
# 6   0.776713  0.359905  0.096117  0.706763  0.365144      ExtremeStress
# 7   0.776713  0.359905  0.096117  0.706763  0.365144  CompensatedStress
# 8   0.776713  0.359905  0.096117  0.706763  0.365144          LowDemand
# 9   0.776713  0.359905  0.096117  0.706763  0.365144       HighBlueNile
# 10  0.335591  0.359905  0.047483  0.701069  0.738340           Baseline
# 11  0.335591  0.359905  0.047483  0.701069  0.738340      ExtremeStress
# 12  0.335591  0.359905  0.047483  0.701069  0.738340  CompensatedStress
# 13  0.335591  0.359905  0.047483  0.701069  0.738340          LowDemand
# 14  0.335591  0.359905  0.047483  0.701069  0.738340       HighBlueNile
#
#      policy        model
# 0   Policy0  NileProblem
# 1   Policy0  NileProblem
# 2   Policy0  NileProblem
# 3   Policy0  NileProblem
# 4   Policy0  NileProblem
# 5   Policy1  NileProblem
# 6   Policy1  NileProblem
# 7   Policy1  NileProblem
# 8   Policy1  NileProblem
# 9   Policy1  NileProblem
# 10  Policy2  NileProblem
# 11  Policy2  NileProblem
# 12  Policy2  NileProblem
# 13  Policy2  NileProblem
# 14  Policy2  NileProblem
#
# [15 rows x 174 columns]

# %%
# merged_df = pd.merge(experiments,outcomes, left_index=True, right_index=True)
# levers = [f"v{i}" for i in range(164)]
# objs = list(outcomes.columns)
# merged_df.loc[merged_df["scenario"] == "OptimScen", levers + objs].reset_index().drop(columns = "index").to_csv("../outputs/baseline_results1.csv",index=True)

# %%
def normalize_objs(df, directions):
    desirability_couples = list()
    working_df = df.copy()
    for i, col in enumerate(df.columns):
        if directions[i] == "min":
            best, worst = df[col].min(), df[col].max()
        elif directions[i] == "max":
            best, worst = df[col].max(), df[col].min()
        desirability_couples.append((worst, best))
        working_df[col] = (df[col] - worst) / (best - worst)

    return working_df, desirability_couples

# %%
from scipy.stats import linregress

# %%
scenario_indexes = {
    scen: list(experiments.loc[experiments["scenario"] == scen].index)
    for scen in experiments["scenario"].unique()
}
slope_dfs = {}
corr_dfs = {}


for scen, indexes in scenario_indexes.items():
    print("---------------------------------")
    print(scen)
    print("---------------------------------")
    norm_df, desire_couples = normalize_objs(
        outcomes.loc[indexes], ["min", "min", "min", "min", "min", "max"]
    )

    cor_template = norm_df.corr()
    reg_template = cor_template.copy()

    for name1 in cor_template.columns:
        for name2 in cor_template.columns:
            if name1 == name2:
                cor_template.at[name1, name2] = None
            #             if name1 == "sudan_90" or name2 == "sudan_90":
            #                 cor_template.at[name1, name2] = None
            #                 reg_template.at[name1, name2] = None
            if cor_template.loc[name1, name2] is None:
                continue

            slope, intercept, r_value, p_value, std_err = linregress(
                x=norm_df[name1], y=norm_df[name2]
            )
            if reg_template.at[name1, name2] == cor_template.at[name1, name2]:
                if abs(slope) > 1:
                    slope = 1 / slope

                reg_template.at[name1, name2] = slope
                reg_template.at[name2, name1] = slope

            # dif_series = abs(norm_df[name1] - norm_df[name2])
            # cor_template.at[name1,name2] = dif_series.mean()

    slope_dfs[scen] = reg_template
    corr_dfs[scen] = cor_template
    print(outcomes.loc[indexes].describe())
    outcomes.loc[indexes].describe().to_excel(f"../plots/tables/{scen}_statistics.xlsx")
# Out:
# ---------------------------------
# Baseline
# ---------------------------------
#         egypt_irr    egypt_90  egypt_low_had   sudan_irr    sudan_90  \
# count  340.000000  340.000000     340.000000  340.000000  340.000000
# mean     5.799038    1.425814       0.277279    0.137928    0.012462
# std      2.807234    0.757129       0.236762    0.196730    0.034875
# min      3.499272    0.508538       0.000000    0.000000    0.000000
# 25%      4.502679    1.051275       0.087500    0.001429    0.000000
# 50%      5.002051    1.285461       0.216667    0.048857    0.000000
# 75%      5.941854    1.527429       0.391667    0.160708    0.000000
# max     18.462717    5.171043       0.883333    0.724290    0.172364
#
#        ethiopia_hydro
# count      340.000000
# mean        13.941639
# std          1.303515
# min          9.424000
# 25%         13.235413
# 50%         14.330341
# 75%         15.012950
# max         15.125298
# ---------------------------------
# ExtremeStress
# ---------------------------------
#         egypt_irr    egypt_90  egypt_low_had   sudan_irr    sudan_90  \
# count  340.000000  340.000000     340.000000  340.000000  340.000000
# mean    34.722569    8.408936       0.881458    0.424944    0.108463
# std      1.017147    0.551409       0.113463    0.291153    0.145535
# min     31.989186    5.749951       0.008333    0.000000    0.000000
# 25%     34.264941    8.467469       0.875000    0.213366    0.000000
# 50%     34.648314    8.557682       0.879167    0.413231    0.036655
# 75%     35.275312    8.568045       0.925000    0.534034    0.189780
# max     38.554764    9.148678       0.937500    1.493090    0.614275
#
#        ethiopia_hydro
# count      340.000000
# mean         9.409129
# std          1.198550
# min          7.598498
# 25%          8.368826
# 50%          8.464827
# 75%         10.739098
# max         10.858176
# ---------------------------------
# CompensatedStress
# ---------------------------------
#         egypt_irr    egypt_90  egypt_low_had   sudan_irr    sudan_90  \
# count  340.000000  340.000000     340.000000  340.000000  340.000000
# mean    17.716827    4.213872       0.624240    0.409783    0.091976
# std      2.429004    1.161624       0.231886    0.314123    0.157142
# min     14.387111    2.358264       0.000000    0.000000    0.000000
# 25%     16.697819    3.248735       0.541667    0.191027    0.000000
# 50%     17.249041    3.782965       0.691667    0.301946    0.000000
# 75%     17.774306    5.125664       0.795833    0.522234    0.157446
# max     28.429571    7.243810       0.887500    1.500626    0.612012
#
#        ethiopia_hydro
# count      340.000000
# mean         9.493995
# std          1.153012
# min          7.598498
# 25%          8.466696
# 50%          8.698325
# 75%         10.759474
# max         10.858368
# ---------------------------------
# LowDemand
# ---------------------------------
#         egypt_irr    egypt_90  egypt_low_had   sudan_irr    sudan_90  \
# count  340.000000  340.000000     340.000000  340.000000  340.000000
# mean     1.717911    0.527347       0.042451    0.088527    0.001228
# std      1.885391    0.640664       0.117193    0.133354    0.006353
# min      0.000000    0.000000       0.000000    0.000000    0.000000
# 25%      0.284174    0.000000       0.000000    0.000000    0.000000
# 50%      1.049519    0.293856       0.000000    0.003718    0.000000
# 75%      2.665055    0.877628       0.029167    0.132878    0.000000
# max     10.023396    3.140925       0.883333    0.485841    0.054159
#
#        ethiopia_hydro
# count      340.000000
# mean        14.251740
# std          1.190916
# min          9.424000
# 25%         14.163074
# 50%         14.629674
# 75%         15.026575
# max         15.125828
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/nanops.py:1723: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   return np.percentile(values, q, axis=1, interpolation=interpolation)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/nanops.py:1723: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   return np.percentile(values, q, axis=1, interpolation=interpolation)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/nanops.py:1723: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   return np.percentile(values, q, axis=1, interpolation=interpolation)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/nanops.py:1723: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   return np.percentile(values, q, axis=1, interpolation=interpolation)
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/nanops.py:1723: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   return np.percentile(values, q, axis=1, interpolation=interpolation)
# ---------------------------------
# HighBlueNile
# ---------------------------------
#         egypt_irr    egypt_90  egypt_low_had   sudan_irr  sudan_90  \
# count  340.000000  340.000000     340.000000  340.000000     340.0
# mean     8.035590    2.435154       0.003051    0.088230       0.0
# std      2.294509    0.612739       0.039728    0.116758       0.0
# min      3.080488    1.012121       0.000000    0.000000       0.0
# 25%      5.989659    1.974308       0.000000    0.000000       0.0
# 50%      8.991610    2.671510       0.000000    0.024364       0.0
# 75%      9.854999    2.835433       0.000000    0.177164       0.0
# max     13.433690    3.969714       0.520833    0.418231       0.0
#
#        ethiopia_hydro
# count      340.000000
# mean        18.625667
# std          1.566079
# min         10.808959
# 25%         18.901276
# 50%         19.101250
# 75%         19.238724
# max         19.261798
# /Library/Frameworks/Python.framework/Versions/3.9/lib/python3.9/site-packages/pandas/core/nanops.py:1723: DeprecationWarning: the `interpolation=` argument to percentile was renamed to `method=`, which has additional options.
# Users of the modes 'nearest', 'lower', 'higher', or 'midpoint' are encouraged to review the method they. (Deprecated NumPy 1.22)
#   return np.percentile(values, q, axis=1, interpolation=interpolation)

# %%
slope, intercept, r_value, p_value, std_err = linregress(
    x=outcomes["egypt_90"], y=outcomes["egypt_irr"]
)
1 / slope
# Out:
# 0.24644479389865073

# %%
pd.set_option("precision", 2)
from matplotlib.colors import LinearSegmentedColormap

my_cmap = LinearSegmentedColormap.from_list(
    "rg", ["salmon", "w", "cornflowerblue"], N=256
)

# %%
obj_names = {
    "egypt_irr": "Egypt Irr. Deficit",
    "egypt_90": "Egypt 90th Irr. Deficit",
    "egypt_low_had": "Egypt Low HAD",
    "sudan_irr": "Sudan Irr. Deficit",
    "sudan_90": "Sudan 90th Irr. Deficit",
    "ethiopia_hydro": "Ethiopia Hydropower",
}

# %%
for scen in experiments["scenario"].unique():
    print("---------")
    print(scen)
    print("---------\n")
    slope_df = (
        slope_dfs[scen]
        .dropna(axis=0, how="all")
        .dropna(axis=1, how="all")
        .fillna(1)
        .rename(columns=obj_names, index=obj_names)
        .style.background_gradient(axis=None, cmap=my_cmap, vmin=-1, vmax=1)
    )
    slope_df
    slope_df.to_excel(f"../plots/tables/{scen}_scenario_regression_slopes.xlsx")

    corr_df = (
        corr_dfs[scen]
        .dropna(axis=0, how="all")
        .dropna(axis=1, how="all")
        .fillna(1)
        .rename(columns=obj_names, index=obj_names)
        .style.background_gradient(axis=None, cmap=my_cmap, vmin=-1, vmax=1)
    )
    corr_df
    corr_df.to_excel(f"../plots/tables/{scen}_scenario_correlations.xlsx")
# Out:
# ---------
# Baseline
# ---------
#
# ---------
# ExtremeStress
# ---------
#
# ---------
# CompensatedStress
# ---------
#
# ---------
# LowDemand
# ---------
#
# ---------
# HighBlueNile
# ---------

# %%
slope_dfs["Baseline"].dropna(axis=0, how="all").dropna(axis=1, how="all").fillna(
    1
).rename(columns=obj_names, index=obj_names).style.background_gradient(
    axis=None, cmap=my_cmap, vmin=-1, vmax=1
)
# Out:
# <style type="text/css">
# #T_810e1_row0_col0, #T_810e1_row1_col1, #T_810e1_row2_col2, #T_810e1_row3_col3, #T_810e1_row4_col4, #T_810e1_row5_col5 {
#   background-color: #6495ed;
#   color: #f1f1f1;
# }
# #T_810e1_row0_col1, #T_810e1_row1_col0 {
#   background-color: #81a9f0;
#   color: #f1f1f1;
# }
# #T_810e1_row0_col2, #T_810e1_row0_col5, #T_810e1_row2_col0, #T_810e1_row5_col0 {
#   background-color: #fdc8c2;
#   color: #000000;
# }
# #T_810e1_row0_col3, #T_810e1_row3_col0 {
#   background-color: #6b9aee;
#   color: #f1f1f1;
# }
# #T_810e1_row0_col4, #T_810e1_row4_col0 {
#   background-color: #9ebdf4;
#   color: #000000;
# }
# #T_810e1_row1_col2, #T_810e1_row2_col1 {
#   background-color: #fca89e;
#   color: #000000;
# }
# #T_810e1_row1_col3, #T_810e1_row3_col1 {
#   background-color: #75a1ef;
#   color: #f1f1f1;
# }
# #T_810e1_row1_col4, #T_810e1_row4_col1 {
#   background-color: #8aaff1;
#   color: #000000;
# }
# #T_810e1_row1_col5, #T_810e1_row5_col1 {
#   background-color: #fcb8b0;
#   color: #000000;
# }
# #T_810e1_row2_col3, #T_810e1_row3_col2 {
#   background-color: #fee7e4;
#   color: #000000;
# }
# #T_810e1_row2_col4, #T_810e1_row4_col2 {
#   background-color: #feece9;
#   color: #000000;
# }
# #T_810e1_row2_col5, #T_810e1_row5_col2 {
#   background-color: #fff6f4;
#   color: #000000;
# }
# #T_810e1_row3_col4, #T_810e1_row4_col3 {
#   background-color: #a2bff4;
#   color: #000000;
# }
# #T_810e1_row3_col5, #T_810e1_row5_col3 {
#   background-color: #fdcdc7;
#   color: #000000;
# }
# #T_810e1_row4_col5, #T_810e1_row5_col4 {
#   background-color: #fdd2cd;
#   color: #000000;
# }
# </style>
# <table id="T_810e1_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Egypt Irr. Deficit</th>
#       <th class="col_heading level0 col1" >Egypt 90th Irr. Deficit</th>
#       <th class="col_heading level0 col2" >Egypt Low HAD</th>
#       <th class="col_heading level0 col3" >Sudan Irr. Deficit</th>
#       <th class="col_heading level0 col4" >Sudan 90th Irr. Deficit</th>
#       <th class="col_heading level0 col5" >Ethiopia Hydropower</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_810e1_level0_row0" class="row_heading level0 row0" >Egypt Irr. Deficit</th>
#       <td id="T_810e1_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_810e1_row0_col1" class="data row0 col1" >0.81</td>
#       <td id="T_810e1_row0_col2" class="data row0 col2" >-0.43</td>
#       <td id="T_810e1_row0_col3" class="data row0 col3" >0.95</td>
#       <td id="T_810e1_row0_col4" class="data row0 col4" >0.62</td>
#       <td id="T_810e1_row0_col5" class="data row0 col5" >-0.43</td>
#     </tr>
#     <tr>
#       <th id="T_810e1_level0_row1" class="row_heading level0 row1" >Egypt 90th Irr. Deficit</th>
#       <td id="T_810e1_row1_col0" class="data row1 col0" >0.81</td>
#       <td id="T_810e1_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_810e1_row1_col2" class="data row1 col2" >-0.69</td>
#       <td id="T_810e1_row1_col3" class="data row1 col3" >0.89</td>
#       <td id="T_810e1_row1_col4" class="data row1 col4" >0.75</td>
#       <td id="T_810e1_row1_col5" class="data row1 col5" >-0.56</td>
#     </tr>
#     <tr>
#       <th id="T_810e1_level0_row2" class="row_heading level0 row2" >Egypt Low HAD</th>
#       <td id="T_810e1_row2_col0" class="data row2 col0" >-0.43</td>
#       <td id="T_810e1_row2_col1" class="data row2 col1" >-0.69</td>
#       <td id="T_810e1_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_810e1_row2_col3" class="data row2 col3" >-0.19</td>
#       <td id="T_810e1_row2_col4" class="data row2 col4" >-0.15</td>
#       <td id="T_810e1_row2_col5" class="data row2 col5" >-0.08</td>
#     </tr>
#     <tr>
#       <th id="T_810e1_level0_row3" class="row_heading level0 row3" >Sudan Irr. Deficit</th>
#       <td id="T_810e1_row3_col0" class="data row3 col0" >0.95</td>
#       <td id="T_810e1_row3_col1" class="data row3 col1" >0.89</td>
#       <td id="T_810e1_row3_col2" class="data row3 col2" >-0.19</td>
#       <td id="T_810e1_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_810e1_row3_col4" class="data row3 col4" >0.60</td>
#       <td id="T_810e1_row3_col5" class="data row3 col5" >-0.40</td>
#     </tr>
#     <tr>
#       <th id="T_810e1_level0_row4" class="row_heading level0 row4" >Sudan 90th Irr. Deficit</th>
#       <td id="T_810e1_row4_col0" class="data row4 col0" >0.62</td>
#       <td id="T_810e1_row4_col1" class="data row4 col1" >0.75</td>
#       <td id="T_810e1_row4_col2" class="data row4 col2" >-0.15</td>
#       <td id="T_810e1_row4_col3" class="data row4 col3" >0.60</td>
#       <td id="T_810e1_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_810e1_row4_col5" class="data row4 col5" >-0.35</td>
#     </tr>
#     <tr>
#       <th id="T_810e1_level0_row5" class="row_heading level0 row5" >Ethiopia Hydropower</th>
#       <td id="T_810e1_row5_col0" class="data row5 col0" >-0.43</td>
#       <td id="T_810e1_row5_col1" class="data row5 col1" >-0.56</td>
#       <td id="T_810e1_row5_col2" class="data row5 col2" >-0.08</td>
#       <td id="T_810e1_row5_col3" class="data row5 col3" >-0.40</td>
#       <td id="T_810e1_row5_col4" class="data row5 col4" >-0.35</td>
#       <td id="T_810e1_row5_col5" class="data row5 col5" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
corr_dfs["Baseline"].dropna(axis=0, how="all").dropna(axis=1, how="all").fillna(
    1
).rename(columns=obj_names, index=obj_names).style.background_gradient(
    axis=None, cmap=my_cmap, vmin=-1, vmax=1
)
# Out:
# <style type="text/css">
# #T_7bb0d_row0_col0, #T_7bb0d_row1_col1, #T_7bb0d_row2_col2, #T_7bb0d_row3_col3, #T_7bb0d_row4_col4, #T_7bb0d_row5_col5 {
#   background-color: #6495ed;
#   color: #f1f1f1;
# }
# #T_7bb0d_row0_col1, #T_7bb0d_row1_col0 {
#   background-color: #6e9cee;
#   color: #f1f1f1;
# }
# #T_7bb0d_row0_col2, #T_7bb0d_row2_col0 {
#   background-color: #fdd9d4;
#   color: #000000;
# }
# #T_7bb0d_row0_col3, #T_7bb0d_row3_col0 {
#   background-color: #99baf3;
#   color: #000000;
# }
# #T_7bb0d_row0_col4, #T_7bb0d_row4_col0 {
#   background-color: #a6c2f5;
#   color: #000000;
# }
# #T_7bb0d_row0_col5, #T_7bb0d_row5_col0 {
#   background-color: #fdd2cd;
#   color: #000000;
# }
# #T_7bb0d_row1_col2, #T_7bb0d_row2_col1 {
#   background-color: #fdcac4;
#   color: #000000;
# }
# #T_7bb0d_row1_col3, #T_7bb0d_row3_col1 {
#   background-color: #96b7f3;
#   color: #000000;
# }
# #T_7bb0d_row1_col4, #T_7bb0d_row4_col1 {
#   background-color: #a1bff4;
#   color: #000000;
# }
# #T_7bb0d_row1_col5, #T_7bb0d_row5_col1 {
#   background-color: #fdcdc7;
#   color: #000000;
# }
# #T_7bb0d_row2_col3, #T_7bb0d_row3_col2 {
#   background-color: #fee7e4;
#   color: #000000;
# }
# #T_7bb0d_row2_col4, #T_7bb0d_row4_col2 {
#   background-color: #fee6e3;
#   color: #000000;
# }
# #T_7bb0d_row2_col5, #T_7bb0d_row5_col2 {
#   background-color: #fff4f2;
#   color: #000000;
# }
# #T_7bb0d_row3_col4, #T_7bb0d_row4_col3 {
#   background-color: #82aaf1;
#   color: #f1f1f1;
# }
# #T_7bb0d_row3_col5, #T_7bb0d_row5_col3 {
#   background-color: #fdc3bc;
#   color: #000000;
# }
# #T_7bb0d_row4_col5, #T_7bb0d_row5_col4 {
#   background-color: #fdd8d3;
#   color: #000000;
# }
# </style>
# <table id="T_7bb0d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Egypt Irr. Deficit</th>
#       <th class="col_heading level0 col1" >Egypt 90th Irr. Deficit</th>
#       <th class="col_heading level0 col2" >Egypt Low HAD</th>
#       <th class="col_heading level0 col3" >Sudan Irr. Deficit</th>
#       <th class="col_heading level0 col4" >Sudan 90th Irr. Deficit</th>
#       <th class="col_heading level0 col5" >Ethiopia Hydropower</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7bb0d_level0_row0" class="row_heading level0 row0" >Egypt Irr. Deficit</th>
#       <td id="T_7bb0d_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_7bb0d_row0_col1" class="data row0 col1" >0.93</td>
#       <td id="T_7bb0d_row0_col2" class="data row0 col2" >-0.30</td>
#       <td id="T_7bb0d_row0_col3" class="data row0 col3" >0.65</td>
#       <td id="T_7bb0d_row0_col4" class="data row0 col4" >0.58</td>
#       <td id="T_7bb0d_row0_col5" class="data row0 col5" >-0.36</td>
#     </tr>
#     <tr>
#       <th id="T_7bb0d_level0_row1" class="row_heading level0 row1" >Egypt 90th Irr. Deficit</th>
#       <td id="T_7bb0d_row1_col0" class="data row1 col0" >0.93</td>
#       <td id="T_7bb0d_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_7bb0d_row1_col2" class="data row1 col2" >-0.42</td>
#       <td id="T_7bb0d_row1_col3" class="data row1 col3" >0.68</td>
#       <td id="T_7bb0d_row1_col4" class="data row1 col4" >0.60</td>
#       <td id="T_7bb0d_row1_col5" class="data row1 col5" >-0.39</td>
#     </tr>
#     <tr>
#       <th id="T_7bb0d_level0_row2" class="row_heading level0 row2" >Egypt Low HAD</th>
#       <td id="T_7bb0d_row2_col0" class="data row2 col0" >-0.30</td>
#       <td id="T_7bb0d_row2_col1" class="data row2 col1" >-0.42</td>
#       <td id="T_7bb0d_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_7bb0d_row2_col3" class="data row2 col3" >-0.19</td>
#       <td id="T_7bb0d_row2_col4" class="data row2 col4" >-0.20</td>
#       <td id="T_7bb0d_row2_col5" class="data row2 col5" >-0.09</td>
#     </tr>
#     <tr>
#       <th id="T_7bb0d_level0_row3" class="row_heading level0 row3" >Sudan Irr. Deficit</th>
#       <td id="T_7bb0d_row3_col0" class="data row3 col0" >0.65</td>
#       <td id="T_7bb0d_row3_col1" class="data row3 col1" >0.68</td>
#       <td id="T_7bb0d_row3_col2" class="data row3 col2" >-0.19</td>
#       <td id="T_7bb0d_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_7bb0d_row3_col4" class="data row3 col4" >0.80</td>
#       <td id="T_7bb0d_row3_col5" class="data row3 col5" >-0.47</td>
#     </tr>
#     <tr>
#       <th id="T_7bb0d_level0_row4" class="row_heading level0 row4" >Sudan 90th Irr. Deficit</th>
#       <td id="T_7bb0d_row4_col0" class="data row4 col0" >0.58</td>
#       <td id="T_7bb0d_row4_col1" class="data row4 col1" >0.60</td>
#       <td id="T_7bb0d_row4_col2" class="data row4 col2" >-0.20</td>
#       <td id="T_7bb0d_row4_col3" class="data row4 col3" >0.80</td>
#       <td id="T_7bb0d_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_7bb0d_row4_col5" class="data row4 col5" >-0.31</td>
#     </tr>
#     <tr>
#       <th id="T_7bb0d_level0_row5" class="row_heading level0 row5" >Ethiopia Hydropower</th>
#       <td id="T_7bb0d_row5_col0" class="data row5 col0" >-0.36</td>
#       <td id="T_7bb0d_row5_col1" class="data row5 col1" >-0.39</td>
#       <td id="T_7bb0d_row5_col2" class="data row5 col2" >-0.09</td>
#       <td id="T_7bb0d_row5_col3" class="data row5 col3" >-0.47</td>
#       <td id="T_7bb0d_row5_col4" class="data row5 col4" >-0.31</td>
#       <td id="T_7bb0d_row5_col5" class="data row5 col5" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
slope_dfs["ExtremeStress"].dropna(axis=0, how="all").dropna(axis=1, how="all").fillna(
    1
).rename(columns=obj_names, index=obj_names).style.background_gradient(
    axis=None, cmap=my_cmap, vmin=-1, vmax=1
)
# Out:
# <style type="text/css">
# #T_0a7d2_row0_col0, #T_0a7d2_row1_col1, #T_0a7d2_row2_col2, #T_0a7d2_row3_col3, #T_0a7d2_row4_col4, #T_0a7d2_row5_col5 {
#   background-color: #6495ed;
#   color: #f1f1f1;
# }
# #T_0a7d2_row0_col1, #T_0a7d2_row1_col0 {
#   background-color: #fff4f2;
#   color: #000000;
# }
# #T_0a7d2_row0_col2, #T_0a7d2_row2_col0 {
#   background-color: #fee7e4;
#   color: #000000;
# }
# #T_0a7d2_row0_col3, #T_0a7d2_row3_col0 {
#   background-color: #fffefd;
#   color: #000000;
# }
# #T_0a7d2_row0_col4, #T_0a7d2_row4_col0 {
#   background-color: #f2f6fe;
#   color: #000000;
# }
# #T_0a7d2_row0_col5, #T_0a7d2_row5_col0 {
#   background-color: #fba59b;
#   color: #000000;
# }
# #T_0a7d2_row1_col2, #T_0a7d2_row1_col5, #T_0a7d2_row2_col1, #T_0a7d2_row5_col1 {
#   background-color: #c6d8f8;
#   color: #000000;
# }
# #T_0a7d2_row1_col3, #T_0a7d2_row3_col1 {
#   background-color: #fff3f1;
#   color: #000000;
# }
# #T_0a7d2_row1_col4, #T_0a7d2_row4_col1 {
#   background-color: #fff5f3;
#   color: #000000;
# }
# #T_0a7d2_row2_col3, #T_0a7d2_row3_col2 {
#   background-color: #fca89e;
#   color: #000000;
# }
# #T_0a7d2_row2_col4, #T_0a7d2_row4_col2 {
#   background-color: #fb978b;
#   color: #000000;
# }
# #T_0a7d2_row2_col5, #T_0a7d2_row5_col2 {
#   background-color: #fff6f4;
#   color: #000000;
# }
# #T_0a7d2_row3_col4, #T_0a7d2_row4_col3 {
#   background-color: #75a1ef;
#   color: #f1f1f1;
# }
# #T_0a7d2_row3_col5, #T_0a7d2_row5_col3 {
#   background-color: #fffaf9;
#   color: #000000;
# }
# #T_0a7d2_row4_col5, #T_0a7d2_row5_col4 {
#   background-color: #feffff;
#   color: #000000;
# }
# </style>
# <table id="T_0a7d2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Egypt Irr. Deficit</th>
#       <th class="col_heading level0 col1" >Egypt 90th Irr. Deficit</th>
#       <th class="col_heading level0 col2" >Egypt Low HAD</th>
#       <th class="col_heading level0 col3" >Sudan Irr. Deficit</th>
#       <th class="col_heading level0 col4" >Sudan 90th Irr. Deficit</th>
#       <th class="col_heading level0 col5" >Ethiopia Hydropower</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0a7d2_level0_row0" class="row_heading level0 row0" >Egypt Irr. Deficit</th>
#       <td id="T_0a7d2_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_0a7d2_row0_col1" class="data row0 col1" >-0.09</td>
#       <td id="T_0a7d2_row0_col2" class="data row0 col2" >-0.19</td>
#       <td id="T_0a7d2_row0_col3" class="data row0 col3" >-0.01</td>
#       <td id="T_0a7d2_row0_col4" class="data row0 col4" >0.08</td>
#       <td id="T_0a7d2_row0_col5" class="data row0 col5" >-0.71</td>
#     </tr>
#     <tr>
#       <th id="T_0a7d2_level0_row1" class="row_heading level0 row1" >Egypt 90th Irr. Deficit</th>
#       <td id="T_0a7d2_row1_col0" class="data row1 col0" >-0.09</td>
#       <td id="T_0a7d2_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_0a7d2_row1_col2" class="data row1 col2" >0.36</td>
#       <td id="T_0a7d2_row1_col3" class="data row1 col3" >-0.10</td>
#       <td id="T_0a7d2_row1_col4" class="data row1 col4" >-0.08</td>
#       <td id="T_0a7d2_row1_col5" class="data row1 col5" >0.36</td>
#     </tr>
#     <tr>
#       <th id="T_0a7d2_level0_row2" class="row_heading level0 row2" >Egypt Low HAD</th>
#       <td id="T_0a7d2_row2_col0" class="data row2 col0" >-0.19</td>
#       <td id="T_0a7d2_row2_col1" class="data row2 col1" >0.36</td>
#       <td id="T_0a7d2_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_0a7d2_row2_col3" class="data row2 col3" >-0.68</td>
#       <td id="T_0a7d2_row2_col4" class="data row2 col4" >-0.82</td>
#       <td id="T_0a7d2_row2_col5" class="data row2 col5" >-0.07</td>
#     </tr>
#     <tr>
#       <th id="T_0a7d2_level0_row3" class="row_heading level0 row3" >Sudan Irr. Deficit</th>
#       <td id="T_0a7d2_row3_col0" class="data row3 col0" >-0.01</td>
#       <td id="T_0a7d2_row3_col1" class="data row3 col1" >-0.10</td>
#       <td id="T_0a7d2_row3_col2" class="data row3 col2" >-0.68</td>
#       <td id="T_0a7d2_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_0a7d2_row3_col4" class="data row3 col4" >0.89</td>
#       <td id="T_0a7d2_row3_col5" class="data row3 col5" >-0.05</td>
#     </tr>
#     <tr>
#       <th id="T_0a7d2_level0_row4" class="row_heading level0 row4" >Sudan 90th Irr. Deficit</th>
#       <td id="T_0a7d2_row4_col0" class="data row4 col0" >0.08</td>
#       <td id="T_0a7d2_row4_col1" class="data row4 col1" >-0.08</td>
#       <td id="T_0a7d2_row4_col2" class="data row4 col2" >-0.82</td>
#       <td id="T_0a7d2_row4_col3" class="data row4 col3" >0.89</td>
#       <td id="T_0a7d2_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_0a7d2_row4_col5" class="data row4 col5" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_0a7d2_level0_row5" class="row_heading level0 row5" >Ethiopia Hydropower</th>
#       <td id="T_0a7d2_row5_col0" class="data row5 col0" >-0.71</td>
#       <td id="T_0a7d2_row5_col1" class="data row5 col1" >0.36</td>
#       <td id="T_0a7d2_row5_col2" class="data row5 col2" >-0.07</td>
#       <td id="T_0a7d2_row5_col3" class="data row5 col3" >-0.05</td>
#       <td id="T_0a7d2_row5_col4" class="data row5 col4" >0.01</td>
#       <td id="T_0a7d2_row5_col5" class="data row5 col5" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
corr_dfs["ExtremeStress"].dropna(axis=0, how="all").dropna(axis=1, how="all").fillna(
    1
).rename(columns=obj_names, index=obj_names).style.background_gradient(
    axis=None, cmap=my_cmap, vmin=-1, vmax=1
)
# Out:
# <style type="text/css">
# #T_548fa_row0_col0, #T_548fa_row1_col1, #T_548fa_row2_col2, #T_548fa_row3_col3, #T_548fa_row4_col4, #T_548fa_row5_col5 {
#   background-color: #6495ed;
#   color: #f1f1f1;
# }
# #T_548fa_row0_col1, #T_548fa_row1_col0, #T_548fa_row1_col3, #T_548fa_row3_col1 {
#   background-color: #fff5f3;
#   color: #000000;
# }
# #T_548fa_row0_col2, #T_548fa_row2_col0 {
#   background-color: #fee0dc;
#   color: #000000;
# }
# #T_548fa_row0_col3, #T_548fa_row3_col0 {
#   background-color: #fffefd;
#   color: #000000;
# }
# #T_548fa_row0_col4, #T_548fa_row4_col0 {
#   background-color: #f7fafe;
#   color: #000000;
# }
# #T_548fa_row0_col5, #T_548fa_row5_col0 {
#   background-color: #fcb3aa;
#   color: #000000;
# }
# #T_548fa_row1_col2, #T_548fa_row2_col1 {
#   background-color: #b4ccf6;
#   color: #000000;
# }
# #T_548fa_row1_col4, #T_548fa_row4_col1 {
#   background-color: #fff8f7;
#   color: #000000;
# }
# #T_548fa_row1_col5, #T_548fa_row5_col1 {
#   background-color: #e6eefc;
#   color: #000000;
# }
# #T_548fa_row2_col3, #T_548fa_row2_col4, #T_548fa_row3_col2, #T_548fa_row4_col2 {
#   background-color: #fdc9c3;
#   color: #000000;
# }
# #T_548fa_row2_col5, #T_548fa_row3_col5, #T_548fa_row5_col2, #T_548fa_row5_col3 {
#   background-color: #fffcfb;
#   color: #000000;
# }
# #T_548fa_row3_col4, #T_548fa_row4_col3 {
#   background-color: #6f9cee;
#   color: #f1f1f1;
# }
# #T_548fa_row4_col5, #T_548fa_row5_col4 {
#   background-color: #feffff;
#   color: #000000;
# }
# </style>
# <table id="T_548fa_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Egypt Irr. Deficit</th>
#       <th class="col_heading level0 col1" >Egypt 90th Irr. Deficit</th>
#       <th class="col_heading level0 col2" >Egypt Low HAD</th>
#       <th class="col_heading level0 col3" >Sudan Irr. Deficit</th>
#       <th class="col_heading level0 col4" >Sudan 90th Irr. Deficit</th>
#       <th class="col_heading level0 col5" >Ethiopia Hydropower</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_548fa_level0_row0" class="row_heading level0 row0" >Egypt Irr. Deficit</th>
#       <td id="T_548fa_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_548fa_row0_col1" class="data row0 col1" >-0.09</td>
#       <td id="T_548fa_row0_col2" class="data row0 col2" >-0.24</td>
#       <td id="T_548fa_row0_col3" class="data row0 col3" >-0.01</td>
#       <td id="T_548fa_row0_col4" class="data row0 col4" >0.05</td>
#       <td id="T_548fa_row0_col5" class="data row0 col5" >-0.60</td>
#     </tr>
#     <tr>
#       <th id="T_548fa_level0_row1" class="row_heading level0 row1" >Egypt 90th Irr. Deficit</th>
#       <td id="T_548fa_row1_col0" class="data row1 col0" >-0.09</td>
#       <td id="T_548fa_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_548fa_row1_col2" class="data row1 col2" >0.48</td>
#       <td id="T_548fa_row1_col3" class="data row1 col3" >-0.08</td>
#       <td id="T_548fa_row1_col4" class="data row1 col4" >-0.06</td>
#       <td id="T_548fa_row1_col5" class="data row1 col5" >0.16</td>
#     </tr>
#     <tr>
#       <th id="T_548fa_level0_row2" class="row_heading level0 row2" >Egypt Low HAD</th>
#       <td id="T_548fa_row2_col0" class="data row2 col0" >-0.24</td>
#       <td id="T_548fa_row2_col1" class="data row2 col1" >0.48</td>
#       <td id="T_548fa_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_548fa_row2_col3" class="data row2 col3" >-0.43</td>
#       <td id="T_548fa_row2_col4" class="data row2 col4" >-0.42</td>
#       <td id="T_548fa_row2_col5" class="data row2 col5" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_548fa_level0_row3" class="row_heading level0 row3" >Sudan Irr. Deficit</th>
#       <td id="T_548fa_row3_col0" class="data row3 col0" >-0.01</td>
#       <td id="T_548fa_row3_col1" class="data row3 col1" >-0.08</td>
#       <td id="T_548fa_row3_col2" class="data row3 col2" >-0.43</td>
#       <td id="T_548fa_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_548fa_row3_col4" class="data row3 col4" >0.93</td>
#       <td id="T_548fa_row3_col5" class="data row3 col5" >-0.02</td>
#     </tr>
#     <tr>
#       <th id="T_548fa_level0_row4" class="row_heading level0 row4" >Sudan 90th Irr. Deficit</th>
#       <td id="T_548fa_row4_col0" class="data row4 col0" >0.05</td>
#       <td id="T_548fa_row4_col1" class="data row4 col1" >-0.06</td>
#       <td id="T_548fa_row4_col2" class="data row4 col2" >-0.42</td>
#       <td id="T_548fa_row4_col3" class="data row4 col3" >0.93</td>
#       <td id="T_548fa_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_548fa_row4_col5" class="data row4 col5" >0.00</td>
#     </tr>
#     <tr>
#       <th id="T_548fa_level0_row5" class="row_heading level0 row5" >Ethiopia Hydropower</th>
#       <td id="T_548fa_row5_col0" class="data row5 col0" >-0.60</td>
#       <td id="T_548fa_row5_col1" class="data row5 col1" >0.16</td>
#       <td id="T_548fa_row5_col2" class="data row5 col2" >-0.02</td>
#       <td id="T_548fa_row5_col3" class="data row5 col3" >-0.02</td>
#       <td id="T_548fa_row5_col4" class="data row5 col4" >0.00</td>
#       <td id="T_548fa_row5_col5" class="data row5 col5" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
slope_dfs["CompensatedStress"].dropna(axis=0, how="all").dropna(
    axis=1, how="all"
).fillna(1).rename(columns=obj_names, index=obj_names).style.background_gradient(
    axis=None, cmap=my_cmap, vmin=-1, vmax=1
)
# Out:
# <style type="text/css">
# #T_10fbd_row0_col0, #T_10fbd_row1_col1, #T_10fbd_row2_col2, #T_10fbd_row3_col3, #T_10fbd_row4_col4, #T_10fbd_row5_col5 {
#   background-color: #6495ed;
#   color: #f1f1f1;
# }
# #T_10fbd_row0_col1, #T_10fbd_row1_col0 {
#   background-color: #a3c0f4;
#   color: #000000;
# }
# #T_10fbd_row0_col2, #T_10fbd_row2_col0 {
#   background-color: #fb9a8f;
#   color: #000000;
# }
# #T_10fbd_row0_col3, #T_10fbd_row3_col0 {
#   background-color: #acc6f5;
#   color: #000000;
# }
# #T_10fbd_row0_col4, #T_10fbd_row4_col0 {
#   background-color: #91b4f2;
#   color: #000000;
# }
# #T_10fbd_row0_col5, #T_10fbd_row5_col0 {
#   background-color: #fb9185;
#   color: #000000;
# }
# #T_10fbd_row1_col2, #T_10fbd_row2_col1 {
#   background-color: #f7fafe;
#   color: #000000;
# }
# #T_10fbd_row1_col3, #T_10fbd_row3_col1 {
#   background-color: #ecf2fd;
#   color: #000000;
# }
# #T_10fbd_row1_col4, #T_10fbd_row4_col1 {
#   background-color: #e9f0fc;
#   color: #000000;
# }
# #T_10fbd_row1_col5, #T_10fbd_row5_col1 {
#   background-color: #dee8fb;
#   color: #000000;
# }
# #T_10fbd_row2_col3, #T_10fbd_row3_col2 {
#   background-color: #fee1dd;
#   color: #000000;
# }
# #T_10fbd_row2_col4, #T_10fbd_row4_col2 {
#   background-color: #fedbd7;
#   color: #000000;
# }
# #T_10fbd_row2_col5, #T_10fbd_row5_col2 {
#   background-color: #fdd7d2;
#   color: #000000;
# }
# #T_10fbd_row3_col4, #T_10fbd_row4_col3 {
#   background-color: #7aa4f0;
#   color: #f1f1f1;
# }
# #T_10fbd_row3_col5, #T_10fbd_row5_col3 {
#   background-color: #fdcbc5;
#   color: #000000;
# }
# #T_10fbd_row4_col5, #T_10fbd_row5_col4 {
#   background-color: #fdcfc9;
#   color: #000000;
# }
# </style>
# <table id="T_10fbd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Egypt Irr. Deficit</th>
#       <th class="col_heading level0 col1" >Egypt 90th Irr. Deficit</th>
#       <th class="col_heading level0 col2" >Egypt Low HAD</th>
#       <th class="col_heading level0 col3" >Sudan Irr. Deficit</th>
#       <th class="col_heading level0 col4" >Sudan 90th Irr. Deficit</th>
#       <th class="col_heading level0 col5" >Ethiopia Hydropower</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_10fbd_level0_row0" class="row_heading level0 row0" >Egypt Irr. Deficit</th>
#       <td id="T_10fbd_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_10fbd_row0_col1" class="data row0 col1" >0.59</td>
#       <td id="T_10fbd_row0_col2" class="data row0 col2" >-0.79</td>
#       <td id="T_10fbd_row0_col3" class="data row0 col3" >0.53</td>
#       <td id="T_10fbd_row0_col4" class="data row0 col4" >0.71</td>
#       <td id="T_10fbd_row0_col5" class="data row0 col5" >-0.86</td>
#     </tr>
#     <tr>
#       <th id="T_10fbd_level0_row1" class="row_heading level0 row1" >Egypt 90th Irr. Deficit</th>
#       <td id="T_10fbd_row1_col0" class="data row1 col0" >0.59</td>
#       <td id="T_10fbd_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_10fbd_row1_col2" class="data row1 col2" >0.05</td>
#       <td id="T_10fbd_row1_col3" class="data row1 col3" >0.12</td>
#       <td id="T_10fbd_row1_col4" class="data row1 col4" >0.14</td>
#       <td id="T_10fbd_row1_col5" class="data row1 col5" >0.22</td>
#     </tr>
#     <tr>
#       <th id="T_10fbd_level0_row2" class="row_heading level0 row2" >Egypt Low HAD</th>
#       <td id="T_10fbd_row2_col0" class="data row2 col0" >-0.79</td>
#       <td id="T_10fbd_row2_col1" class="data row2 col1" >0.05</td>
#       <td id="T_10fbd_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_10fbd_row2_col3" class="data row2 col3" >-0.24</td>
#       <td id="T_10fbd_row2_col4" class="data row2 col4" >-0.29</td>
#       <td id="T_10fbd_row2_col5" class="data row2 col5" >-0.31</td>
#     </tr>
#     <tr>
#       <th id="T_10fbd_level0_row3" class="row_heading level0 row3" >Sudan Irr. Deficit</th>
#       <td id="T_10fbd_row3_col0" class="data row3 col0" >0.53</td>
#       <td id="T_10fbd_row3_col1" class="data row3 col1" >0.12</td>
#       <td id="T_10fbd_row3_col2" class="data row3 col2" >-0.24</td>
#       <td id="T_10fbd_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_10fbd_row3_col4" class="data row3 col4" >0.85</td>
#       <td id="T_10fbd_row3_col5" class="data row3 col5" >-0.41</td>
#     </tr>
#     <tr>
#       <th id="T_10fbd_level0_row4" class="row_heading level0 row4" >Sudan 90th Irr. Deficit</th>
#       <td id="T_10fbd_row4_col0" class="data row4 col0" >0.71</td>
#       <td id="T_10fbd_row4_col1" class="data row4 col1" >0.14</td>
#       <td id="T_10fbd_row4_col2" class="data row4 col2" >-0.29</td>
#       <td id="T_10fbd_row4_col3" class="data row4 col3" >0.85</td>
#       <td id="T_10fbd_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_10fbd_row4_col5" class="data row4 col5" >-0.38</td>
#     </tr>
#     <tr>
#       <th id="T_10fbd_level0_row5" class="row_heading level0 row5" >Ethiopia Hydropower</th>
#       <td id="T_10fbd_row5_col0" class="data row5 col0" >-0.86</td>
#       <td id="T_10fbd_row5_col1" class="data row5 col1" >0.22</td>
#       <td id="T_10fbd_row5_col2" class="data row5 col2" >-0.31</td>
#       <td id="T_10fbd_row5_col3" class="data row5 col3" >-0.41</td>
#       <td id="T_10fbd_row5_col4" class="data row5 col4" >-0.38</td>
#       <td id="T_10fbd_row5_col5" class="data row5 col5" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
corr_dfs["CompensatedStress"].dropna(axis=0, how="all").dropna(
    axis=1, how="all"
).fillna(1).rename(columns=obj_names, index=obj_names).style.background_gradient(
    axis=None, cmap=my_cmap, vmin=-1, vmax=1
)
# Out:
# <style type="text/css">
# #T_6c0c2_row0_col0, #T_6c0c2_row1_col1, #T_6c0c2_row2_col2, #T_6c0c2_row3_col3, #T_6c0c2_row4_col4, #T_6c0c2_row5_col5 {
#   background-color: #6495ed;
#   color: #f1f1f1;
# }
# #T_6c0c2_row0_col1, #T_6c0c2_row1_col0 {
#   background-color: #bdd2f7;
#   color: #000000;
# }
# #T_6c0c2_row0_col2, #T_6c0c2_row2_col0 {
#   background-color: #fcbdb5;
#   color: #000000;
# }
# #T_6c0c2_row0_col3, #T_6c0c2_row3_col0 {
#   background-color: #bad0f7;
#   color: #000000;
# }
# #T_6c0c2_row0_col4, #T_6c0c2_row4_col0 {
#   background-color: #b5cdf6;
#   color: #000000;
# }
# #T_6c0c2_row0_col5, #T_6c0c2_row5_col0 {
#   background-color: #fdc9c3;
#   color: #000000;
# }
# #T_6c0c2_row1_col2, #T_6c0c2_row2_col1 {
#   background-color: #f8fafe;
#   color: #000000;
# }
# #T_6c0c2_row1_col3, #T_6c0c2_row3_col1 {
#   background-color: #eaf0fd;
#   color: #000000;
# }
# #T_6c0c2_row1_col4, #T_6c0c2_row4_col1 {
#   background-color: #ebf1fd;
#   color: #000000;
# }
# #T_6c0c2_row1_col5, #T_6c0c2_row5_col1 {
#   background-color: #e9f0fc;
#   color: #000000;
# }
# #T_6c0c2_row2_col3, #T_6c0c2_row3_col2 {
#   background-color: #fdd9d4;
#   color: #000000;
# }
# #T_6c0c2_row2_col4, #T_6c0c2_row4_col2 {
#   background-color: #fedad6;
#   color: #000000;
# }
# #T_6c0c2_row2_col5, #T_6c0c2_row5_col2 {
#   background-color: #fee2de;
#   color: #000000;
# }
# #T_6c0c2_row3_col4, #T_6c0c2_row4_col3 {
#   background-color: #6a99ee;
#   color: #f1f1f1;
# }
# #T_6c0c2_row3_col5, #T_6c0c2_row5_col3 {
#   background-color: #fee0dc;
#   color: #000000;
# }
# #T_6c0c2_row4_col5, #T_6c0c2_row5_col4 {
#   background-color: #fedcd8;
#   color: #000000;
# }
# </style>
# <table id="T_6c0c2_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Egypt Irr. Deficit</th>
#       <th class="col_heading level0 col1" >Egypt 90th Irr. Deficit</th>
#       <th class="col_heading level0 col2" >Egypt Low HAD</th>
#       <th class="col_heading level0 col3" >Sudan Irr. Deficit</th>
#       <th class="col_heading level0 col4" >Sudan 90th Irr. Deficit</th>
#       <th class="col_heading level0 col5" >Ethiopia Hydropower</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6c0c2_level0_row0" class="row_heading level0 row0" >Egypt Irr. Deficit</th>
#       <td id="T_6c0c2_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_6c0c2_row0_col1" class="data row0 col1" >0.43</td>
#       <td id="T_6c0c2_row0_col2" class="data row0 col2" >-0.52</td>
#       <td id="T_6c0c2_row0_col3" class="data row0 col3" >0.44</td>
#       <td id="T_6c0c2_row0_col4" class="data row0 col4" >0.48</td>
#       <td id="T_6c0c2_row0_col5" class="data row0 col5" >-0.42</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c2_level0_row1" class="row_heading level0 row1" >Egypt 90th Irr. Deficit</th>
#       <td id="T_6c0c2_row1_col0" class="data row1 col0" >0.43</td>
#       <td id="T_6c0c2_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_6c0c2_row1_col2" class="data row1 col2" >0.04</td>
#       <td id="T_6c0c2_row1_col3" class="data row1 col3" >0.14</td>
#       <td id="T_6c0c2_row1_col4" class="data row1 col4" >0.13</td>
#       <td id="T_6c0c2_row1_col5" class="data row1 col5" >0.15</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c2_level0_row2" class="row_heading level0 row2" >Egypt Low HAD</th>
#       <td id="T_6c0c2_row2_col0" class="data row2 col0" >-0.52</td>
#       <td id="T_6c0c2_row2_col1" class="data row2 col1" >0.04</td>
#       <td id="T_6c0c2_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_6c0c2_row2_col3" class="data row2 col3" >-0.30</td>
#       <td id="T_6c0c2_row2_col4" class="data row2 col4" >-0.29</td>
#       <td id="T_6c0c2_row2_col5" class="data row2 col5" >-0.23</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c2_level0_row3" class="row_heading level0 row3" >Sudan Irr. Deficit</th>
#       <td id="T_6c0c2_row3_col0" class="data row3 col0" >0.44</td>
#       <td id="T_6c0c2_row3_col1" class="data row3 col1" >0.14</td>
#       <td id="T_6c0c2_row3_col2" class="data row3 col2" >-0.30</td>
#       <td id="T_6c0c2_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_6c0c2_row3_col4" class="data row3 col4" >0.95</td>
#       <td id="T_6c0c2_row3_col5" class="data row3 col5" >-0.24</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c2_level0_row4" class="row_heading level0 row4" >Sudan 90th Irr. Deficit</th>
#       <td id="T_6c0c2_row4_col0" class="data row4 col0" >0.48</td>
#       <td id="T_6c0c2_row4_col1" class="data row4 col1" >0.13</td>
#       <td id="T_6c0c2_row4_col2" class="data row4 col2" >-0.29</td>
#       <td id="T_6c0c2_row4_col3" class="data row4 col3" >0.95</td>
#       <td id="T_6c0c2_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_6c0c2_row4_col5" class="data row4 col5" >-0.28</td>
#     </tr>
#     <tr>
#       <th id="T_6c0c2_level0_row5" class="row_heading level0 row5" >Ethiopia Hydropower</th>
#       <td id="T_6c0c2_row5_col0" class="data row5 col0" >-0.42</td>
#       <td id="T_6c0c2_row5_col1" class="data row5 col1" >0.15</td>
#       <td id="T_6c0c2_row5_col2" class="data row5 col2" >-0.23</td>
#       <td id="T_6c0c2_row5_col3" class="data row5 col3" >-0.24</td>
#       <td id="T_6c0c2_row5_col4" class="data row5 col4" >-0.28</td>
#       <td id="T_6c0c2_row5_col5" class="data row5 col5" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
slope_dfs["LowDemand"].dropna(axis=0, how="all").dropna(axis=1, how="all").fillna(
    1
).rename(columns=obj_names, index=obj_names).style.background_gradient(
    axis=None, cmap=my_cmap, vmin=-1, vmax=1
)
# Out:
# <style type="text/css">
# #T_82606_row0_col0, #T_82606_row1_col1, #T_82606_row2_col2, #T_82606_row3_col3, #T_82606_row4_col4, #T_82606_row5_col5 {
#   background-color: #6495ed;
#   color: #f1f1f1;
# }
# #T_82606_row0_col1, #T_82606_row1_col0 {
#   background-color: #6e9cee;
#   color: #f1f1f1;
# }
# #T_82606_row0_col2, #T_82606_row2_col0 {
#   background-color: #fff5f3;
#   color: #000000;
# }
# #T_82606_row0_col3, #T_82606_row2_col3, #T_82606_row3_col0, #T_82606_row3_col2 {
#   background-color: #bed3f7;
#   color: #000000;
# }
# #T_82606_row0_col4, #T_82606_row4_col0 {
#   background-color: #e5edfc;
#   color: #000000;
# }
# #T_82606_row0_col5, #T_82606_row5_col0 {
#   background-color: #fededa;
#   color: #000000;
# }
# #T_82606_row1_col2, #T_82606_row2_col1 {
#   background-color: #fff8f7;
#   color: #000000;
# }
# #T_82606_row1_col3, #T_82606_row3_col1 {
#   background-color: #cbdcf9;
#   color: #000000;
# }
# #T_82606_row1_col4, #T_82606_row4_col1 {
#   background-color: #e6eefc;
#   color: #000000;
# }
# #T_82606_row1_col5, #T_82606_row5_col1 {
#   background-color: #fee3df;
#   color: #000000;
# }
# #T_82606_row2_col4, #T_82606_row4_col2 {
#   background-color: #dbe6fb;
#   color: #000000;
# }
# #T_82606_row2_col5, #T_82606_row5_col2 {
#   background-color: #fedad6;
#   color: #000000;
# }
# #T_82606_row3_col4, #T_82606_row4_col3 {
#   background-color: #dee8fb;
#   color: #000000;
# }
# #T_82606_row3_col5, #T_82606_row5_col3 {
#   background-color: #fdd7d2;
#   color: #000000;
# }
# #T_82606_row4_col5, #T_82606_row5_col4 {
#   background-color: #fee1dd;
#   color: #000000;
# }
# </style>
# <table id="T_82606_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Egypt Irr. Deficit</th>
#       <th class="col_heading level0 col1" >Egypt 90th Irr. Deficit</th>
#       <th class="col_heading level0 col2" >Egypt Low HAD</th>
#       <th class="col_heading level0 col3" >Sudan Irr. Deficit</th>
#       <th class="col_heading level0 col4" >Sudan 90th Irr. Deficit</th>
#       <th class="col_heading level0 col5" >Ethiopia Hydropower</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_82606_level0_row0" class="row_heading level0 row0" >Egypt Irr. Deficit</th>
#       <td id="T_82606_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_82606_row0_col1" class="data row0 col1" >0.93</td>
#       <td id="T_82606_row0_col2" class="data row0 col2" >-0.08</td>
#       <td id="T_82606_row0_col3" class="data row0 col3" >0.42</td>
#       <td id="T_82606_row0_col4" class="data row0 col4" >0.17</td>
#       <td id="T_82606_row0_col5" class="data row0 col5" >-0.26</td>
#     </tr>
#     <tr>
#       <th id="T_82606_level0_row1" class="row_heading level0 row1" >Egypt 90th Irr. Deficit</th>
#       <td id="T_82606_row1_col0" class="data row1 col0" >0.93</td>
#       <td id="T_82606_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_82606_row1_col2" class="data row1 col2" >-0.06</td>
#       <td id="T_82606_row1_col3" class="data row1 col3" >0.33</td>
#       <td id="T_82606_row1_col4" class="data row1 col4" >0.16</td>
#       <td id="T_82606_row1_col5" class="data row1 col5" >-0.22</td>
#     </tr>
#     <tr>
#       <th id="T_82606_level0_row2" class="row_heading level0 row2" >Egypt Low HAD</th>
#       <td id="T_82606_row2_col0" class="data row2 col0" >-0.08</td>
#       <td id="T_82606_row2_col1" class="data row2 col1" >-0.06</td>
#       <td id="T_82606_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_82606_row2_col3" class="data row2 col3" >0.42</td>
#       <td id="T_82606_row2_col4" class="data row2 col4" >0.23</td>
#       <td id="T_82606_row2_col5" class="data row2 col5" >-0.29</td>
#     </tr>
#     <tr>
#       <th id="T_82606_level0_row3" class="row_heading level0 row3" >Sudan Irr. Deficit</th>
#       <td id="T_82606_row3_col0" class="data row3 col0" >0.42</td>
#       <td id="T_82606_row3_col1" class="data row3 col1" >0.33</td>
#       <td id="T_82606_row3_col2" class="data row3 col2" >0.42</td>
#       <td id="T_82606_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_82606_row3_col4" class="data row3 col4" >0.21</td>
#       <td id="T_82606_row3_col5" class="data row3 col5" >-0.32</td>
#     </tr>
#     <tr>
#       <th id="T_82606_level0_row4" class="row_heading level0 row4" >Sudan 90th Irr. Deficit</th>
#       <td id="T_82606_row4_col0" class="data row4 col0" >0.17</td>
#       <td id="T_82606_row4_col1" class="data row4 col1" >0.16</td>
#       <td id="T_82606_row4_col2" class="data row4 col2" >0.23</td>
#       <td id="T_82606_row4_col3" class="data row4 col3" >0.21</td>
#       <td id="T_82606_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_82606_row4_col5" class="data row4 col5" >-0.24</td>
#     </tr>
#     <tr>
#       <th id="T_82606_level0_row5" class="row_heading level0 row5" >Ethiopia Hydropower</th>
#       <td id="T_82606_row5_col0" class="data row5 col0" >-0.26</td>
#       <td id="T_82606_row5_col1" class="data row5 col1" >-0.22</td>
#       <td id="T_82606_row5_col2" class="data row5 col2" >-0.29</td>
#       <td id="T_82606_row5_col3" class="data row5 col3" >-0.32</td>
#       <td id="T_82606_row5_col4" class="data row5 col4" >-0.24</td>
#       <td id="T_82606_row5_col5" class="data row5 col5" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
corr_dfs["LowDemand"].dropna(axis=0, how="all").dropna(axis=1, how="all").fillna(
    1
).rename(columns=obj_names, index=obj_names).style.background_gradient(
    axis=None, cmap=my_cmap, vmin=-1, vmax=1
)
# Out:
# <style type="text/css">
# #T_22df3_row0_col0, #T_22df3_row1_col1, #T_22df3_row2_col2, #T_22df3_row3_col3, #T_22df3_row4_col4, #T_22df3_row5_col5 {
#   background-color: #6495ed;
#   color: #f1f1f1;
# }
# #T_22df3_row0_col1, #T_22df3_row1_col0 {
#   background-color: #6596ed;
#   color: #f1f1f1;
# }
# #T_22df3_row0_col2, #T_22df3_row2_col0 {
#   background-color: #fef0ee;
#   color: #000000;
# }
# #T_22df3_row0_col3, #T_22df3_row1_col4, #T_22df3_row3_col0, #T_22df3_row4_col1 {
#   background-color: #d3e1fa;
#   color: #000000;
# }
# #T_22df3_row0_col4, #T_22df3_row2_col4, #T_22df3_row4_col0, #T_22df3_row4_col2 {
#   background-color: #d6e3fa;
#   color: #000000;
# }
# #T_22df3_row0_col5, #T_22df3_row5_col0 {
#   background-color: #fee1dd;
#   color: #000000;
# }
# #T_22df3_row1_col2, #T_22df3_row2_col1 {
#   background-color: #fff4f2;
#   color: #000000;
# }
# #T_22df3_row1_col3, #T_22df3_row3_col1 {
#   background-color: #d9e5fb;
#   color: #000000;
# }
# #T_22df3_row1_col5, #T_22df3_row5_col1 {
#   background-color: #fee4e1;
#   color: #000000;
# }
# #T_22df3_row2_col3, #T_22df3_row3_col2 {
#   background-color: #e0eafb;
#   color: #000000;
# }
# #T_22df3_row2_col5, #T_22df3_row5_col2 {
#   background-color: #fee8e5;
#   color: #000000;
# }
# #T_22df3_row3_col4, #T_22df3_row4_col3 {
#   background-color: #b1c9f6;
#   color: #000000;
# }
# #T_22df3_row3_col5, #T_22df3_row5_col3 {
#   background-color: #fdcac4;
#   color: #000000;
# }
# #T_22df3_row4_col5, #T_22df3_row5_col4 {
#   background-color: #feeeec;
#   color: #000000;
# }
# </style>
# <table id="T_22df3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Egypt Irr. Deficit</th>
#       <th class="col_heading level0 col1" >Egypt 90th Irr. Deficit</th>
#       <th class="col_heading level0 col2" >Egypt Low HAD</th>
#       <th class="col_heading level0 col3" >Sudan Irr. Deficit</th>
#       <th class="col_heading level0 col4" >Sudan 90th Irr. Deficit</th>
#       <th class="col_heading level0 col5" >Ethiopia Hydropower</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22df3_level0_row0" class="row_heading level0 row0" >Egypt Irr. Deficit</th>
#       <td id="T_22df3_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_22df3_row0_col1" class="data row0 col1" >0.99</td>
#       <td id="T_22df3_row0_col2" class="data row0 col2" >-0.12</td>
#       <td id="T_22df3_row0_col3" class="data row0 col3" >0.28</td>
#       <td id="T_22df3_row0_col4" class="data row0 col4" >0.27</td>
#       <td id="T_22df3_row0_col5" class="data row0 col5" >-0.24</td>
#     </tr>
#     <tr>
#       <th id="T_22df3_level0_row1" class="row_heading level0 row1" >Egypt 90th Irr. Deficit</th>
#       <td id="T_22df3_row1_col0" class="data row1 col0" >0.99</td>
#       <td id="T_22df3_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_22df3_row1_col2" class="data row1 col2" >-0.09</td>
#       <td id="T_22df3_row1_col3" class="data row1 col3" >0.25</td>
#       <td id="T_22df3_row1_col4" class="data row1 col4" >0.29</td>
#       <td id="T_22df3_row1_col5" class="data row1 col5" >-0.21</td>
#     </tr>
#     <tr>
#       <th id="T_22df3_level0_row2" class="row_heading level0 row2" >Egypt Low HAD</th>
#       <td id="T_22df3_row2_col0" class="data row2 col0" >-0.12</td>
#       <td id="T_22df3_row2_col1" class="data row2 col1" >-0.09</td>
#       <td id="T_22df3_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_22df3_row2_col3" class="data row2 col3" >0.20</td>
#       <td id="T_22df3_row2_col4" class="data row2 col4" >0.26</td>
#       <td id="T_22df3_row2_col5" class="data row2 col5" >-0.18</td>
#     </tr>
#     <tr>
#       <th id="T_22df3_level0_row3" class="row_heading level0 row3" >Sudan Irr. Deficit</th>
#       <td id="T_22df3_row3_col0" class="data row3 col0" >0.28</td>
#       <td id="T_22df3_row3_col1" class="data row3 col1" >0.25</td>
#       <td id="T_22df3_row3_col2" class="data row3 col2" >0.20</td>
#       <td id="T_22df3_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_22df3_row3_col4" class="data row3 col4" >0.50</td>
#       <td id="T_22df3_row3_col5" class="data row3 col5" >-0.42</td>
#     </tr>
#     <tr>
#       <th id="T_22df3_level0_row4" class="row_heading level0 row4" >Sudan 90th Irr. Deficit</th>
#       <td id="T_22df3_row4_col0" class="data row4 col0" >0.27</td>
#       <td id="T_22df3_row4_col1" class="data row4 col1" >0.29</td>
#       <td id="T_22df3_row4_col2" class="data row4 col2" >0.26</td>
#       <td id="T_22df3_row4_col3" class="data row4 col3" >0.50</td>
#       <td id="T_22df3_row4_col4" class="data row4 col4" >1.00</td>
#       <td id="T_22df3_row4_col5" class="data row4 col5" >-0.14</td>
#     </tr>
#     <tr>
#       <th id="T_22df3_level0_row5" class="row_heading level0 row5" >Ethiopia Hydropower</th>
#       <td id="T_22df3_row5_col0" class="data row5 col0" >-0.24</td>
#       <td id="T_22df3_row5_col1" class="data row5 col1" >-0.21</td>
#       <td id="T_22df3_row5_col2" class="data row5 col2" >-0.18</td>
#       <td id="T_22df3_row5_col3" class="data row5 col3" >-0.42</td>
#       <td id="T_22df3_row5_col4" class="data row5 col4" >-0.14</td>
#       <td id="T_22df3_row5_col5" class="data row5 col5" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
slope_dfs["HighBlueNile"].dropna(axis=0, how="all").dropna(axis=1, how="all").fillna(
    1
).rename(columns=obj_names, index=obj_names).style.background_gradient(
    axis=None, cmap=my_cmap, vmin=-1, vmax=1
)
# Out:
# <style type="text/css">
# #T_2414d_row0_col0, #T_2414d_row1_col1, #T_2414d_row2_col2, #T_2414d_row3_col3, #T_2414d_row4_col4 {
#   background-color: #6495ed;
#   color: #f1f1f1;
# }
# #T_2414d_row0_col1, #T_2414d_row1_col0 {
#   background-color: #709dee;
#   color: #f1f1f1;
# }
# #T_2414d_row0_col2, #T_2414d_row2_col0 {
#   background-color: #fffefd;
#   color: #000000;
# }
# #T_2414d_row0_col3, #T_2414d_row3_col0 {
#   background-color: #fee3df;
#   color: #000000;
# }
# #T_2414d_row0_col4, #T_2414d_row4_col0 {
#   background-color: #fdd8d3;
#   color: #000000;
# }
# #T_2414d_row1_col2, #T_2414d_row2_col1 {
#   background-color: #fffffe;
#   color: #000000;
# }
# #T_2414d_row1_col3, #T_2414d_row3_col1 {
#   background-color: #fff4f2;
#   color: #000000;
# }
# #T_2414d_row1_col4, #T_2414d_row4_col1 {
#   background-color: #fdcec8;
#   color: #000000;
# }
# #T_2414d_row2_col3, #T_2414d_row3_col2 {
#   background-color: #8aaff1;
#   color: #000000;
# }
# #T_2414d_row2_col4, #T_2414d_row4_col2 {
#   background-color: #fff6f4;
#   color: #000000;
# }
# #T_2414d_row3_col4, #T_2414d_row4_col3 {
#   background-color: #feeae7;
#   color: #000000;
# }
# </style>
# <table id="T_2414d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Egypt Irr. Deficit</th>
#       <th class="col_heading level0 col1" >Egypt 90th Irr. Deficit</th>
#       <th class="col_heading level0 col2" >Egypt Low HAD</th>
#       <th class="col_heading level0 col3" >Sudan Irr. Deficit</th>
#       <th class="col_heading level0 col4" >Ethiopia Hydropower</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2414d_level0_row0" class="row_heading level0 row0" >Egypt Irr. Deficit</th>
#       <td id="T_2414d_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_2414d_row0_col1" class="data row0 col1" >0.92</td>
#       <td id="T_2414d_row0_col2" class="data row0 col2" >-0.02</td>
#       <td id="T_2414d_row0_col3" class="data row0 col3" >-0.22</td>
#       <td id="T_2414d_row0_col4" class="data row0 col4" >-0.31</td>
#     </tr>
#     <tr>
#       <th id="T_2414d_level0_row1" class="row_heading level0 row1" >Egypt 90th Irr. Deficit</th>
#       <td id="T_2414d_row1_col0" class="data row1 col0" >0.92</td>
#       <td id="T_2414d_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_2414d_row1_col2" class="data row1 col2" >-0.01</td>
#       <td id="T_2414d_row1_col3" class="data row1 col3" >-0.09</td>
#       <td id="T_2414d_row1_col4" class="data row1 col4" >-0.39</td>
#     </tr>
#     <tr>
#       <th id="T_2414d_level0_row2" class="row_heading level0 row2" >Egypt Low HAD</th>
#       <td id="T_2414d_row2_col0" class="data row2 col0" >-0.02</td>
#       <td id="T_2414d_row2_col1" class="data row2 col1" >-0.01</td>
#       <td id="T_2414d_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_2414d_row2_col3" class="data row2 col3" >0.76</td>
#       <td id="T_2414d_row2_col4" class="data row2 col4" >-0.07</td>
#     </tr>
#     <tr>
#       <th id="T_2414d_level0_row3" class="row_heading level0 row3" >Sudan Irr. Deficit</th>
#       <td id="T_2414d_row3_col0" class="data row3 col0" >-0.22</td>
#       <td id="T_2414d_row3_col1" class="data row3 col1" >-0.09</td>
#       <td id="T_2414d_row3_col2" class="data row3 col2" >0.76</td>
#       <td id="T_2414d_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_2414d_row3_col4" class="data row3 col4" >-0.17</td>
#     </tr>
#     <tr>
#       <th id="T_2414d_level0_row4" class="row_heading level0 row4" >Ethiopia Hydropower</th>
#       <td id="T_2414d_row4_col0" class="data row4 col0" >-0.31</td>
#       <td id="T_2414d_row4_col1" class="data row4 col1" >-0.39</td>
#       <td id="T_2414d_row4_col2" class="data row4 col2" >-0.07</td>
#       <td id="T_2414d_row4_col3" class="data row4 col3" >-0.17</td>
#       <td id="T_2414d_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
corr_dfs["HighBlueNile"].dropna(axis=0, how="all").dropna(axis=1, how="all").fillna(
    1
).rename(columns=obj_names, index=obj_names).style.background_gradient(
    axis=None, cmap=my_cmap, vmin=-1, vmax=1
)
# Out:
# <style type="text/css">
# #T_09520_row0_col0, #T_09520_row1_col1, #T_09520_row2_col2, #T_09520_row3_col3, #T_09520_row4_col4 {
#   background-color: #6495ed;
#   color: #f1f1f1;
# }
# #T_09520_row0_col1, #T_09520_row1_col0 {
#   background-color: #6697ed;
#   color: #f1f1f1;
# }
# #T_09520_row0_col2, #T_09520_row2_col0 {
#   background-color: #fffaf9;
#   color: #000000;
# }
# #T_09520_row0_col3, #T_09520_row3_col0 {
#   background-color: #fee9e6;
#   color: #000000;
# }
# #T_09520_row0_col4, #T_09520_row4_col0 {
#   background-color: #fdd0ca;
#   color: #000000;
# }
# #T_09520_row1_col2, #T_09520_row2_col1 {
#   background-color: #fffefd;
#   color: #000000;
# }
# #T_09520_row1_col3, #T_09520_row3_col1 {
#   background-color: #fff7f6;
#   color: #000000;
# }
# #T_09520_row1_col4, #T_09520_row4_col1 {
#   background-color: #fdc8c2;
#   color: #000000;
# }
# #T_09520_row2_col3, #T_09520_row3_col2 {
#   background-color: #dfe9fb;
#   color: #000000;
# }
# #T_09520_row2_col4, #T_09520_row4_col2 {
#   background-color: #fffcfb;
#   color: #000000;
# }
# #T_09520_row3_col4, #T_09520_row4_col3 {
#   background-color: #fedfdb;
#   color: #000000;
# }
# </style>
# <table id="T_09520_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Egypt Irr. Deficit</th>
#       <th class="col_heading level0 col1" >Egypt 90th Irr. Deficit</th>
#       <th class="col_heading level0 col2" >Egypt Low HAD</th>
#       <th class="col_heading level0 col3" >Sudan Irr. Deficit</th>
#       <th class="col_heading level0 col4" >Ethiopia Hydropower</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_09520_level0_row0" class="row_heading level0 row0" >Egypt Irr. Deficit</th>
#       <td id="T_09520_row0_col0" class="data row0 col0" >1.00</td>
#       <td id="T_09520_row0_col1" class="data row0 col1" >0.98</td>
#       <td id="T_09520_row0_col2" class="data row0 col2" >-0.05</td>
#       <td id="T_09520_row0_col3" class="data row0 col3" >-0.18</td>
#       <td id="T_09520_row0_col4" class="data row0 col4" >-0.37</td>
#     </tr>
#     <tr>
#       <th id="T_09520_level0_row1" class="row_heading level0 row1" >Egypt 90th Irr. Deficit</th>
#       <td id="T_09520_row1_col0" class="data row1 col0" >0.98</td>
#       <td id="T_09520_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_09520_row1_col2" class="data row1 col2" >-0.01</td>
#       <td id="T_09520_row1_col3" class="data row1 col3" >-0.07</td>
#       <td id="T_09520_row1_col4" class="data row1 col4" >-0.43</td>
#     </tr>
#     <tr>
#       <th id="T_09520_level0_row2" class="row_heading level0 row2" >Egypt Low HAD</th>
#       <td id="T_09520_row2_col0" class="data row2 col0" >-0.05</td>
#       <td id="T_09520_row2_col1" class="data row2 col1" >-0.01</td>
#       <td id="T_09520_row2_col2" class="data row2 col2" >1.00</td>
#       <td id="T_09520_row2_col3" class="data row2 col3" >0.21</td>
#       <td id="T_09520_row2_col4" class="data row2 col4" >-0.03</td>
#     </tr>
#     <tr>
#       <th id="T_09520_level0_row3" class="row_heading level0 row3" >Sudan Irr. Deficit</th>
#       <td id="T_09520_row3_col0" class="data row3 col0" >-0.18</td>
#       <td id="T_09520_row3_col1" class="data row3 col1" >-0.07</td>
#       <td id="T_09520_row3_col2" class="data row3 col2" >0.21</td>
#       <td id="T_09520_row3_col3" class="data row3 col3" >1.00</td>
#       <td id="T_09520_row3_col4" class="data row3 col4" >-0.26</td>
#     </tr>
#     <tr>
#       <th id="T_09520_level0_row4" class="row_heading level0 row4" >Ethiopia Hydropower</th>
#       <td id="T_09520_row4_col0" class="data row4 col0" >-0.37</td>
#       <td id="T_09520_row4_col1" class="data row4 col1" >-0.43</td>
#       <td id="T_09520_row4_col2" class="data row4 col2" >-0.03</td>
#       <td id="T_09520_row4_col3" class="data row4 col3" >-0.26</td>
#       <td id="T_09520_row4_col4" class="data row4 col4" >1.00</td>
#     </tr>
#   </tbody>
# </table>

# %%
solution_indices = [271, 328, 265, 86, 165, 248]
solution_names = [
    "Best Egypt Irr.",
    "Best Egypt 90$^{th}$",
    "Best Egypt HAD",
    "Best Ethiopia Hydropower",
    "Compromise: Percentile",
    "Compromise: Absolute",
]

policy_colors = {
    "Best Egypt 90$^{th}$": "#0195fb",
    "Best Egypt HAD": "#6C0C86",
    "Compromise: Absolute": "orchid",
    "Best Ethiopia Hydropower": "#41ab5d",
    "Best Egypt Irr.": "#fdaa09",
    "Compromise: Percentile": "chocolate",
    "All Solutions": "#bdbdbd",
}

directions_dict = {
    "egypt_irr": "min",
    "egypt_90": "min",
    "egypt_low_had": "min",
    "sudan_irr": "min",
    "sudan_90": "min",
    "ethiopia_hydro": "max",
}

for scen in experiments["scenario"].unique():
    print("---------")
    print(scen)
    print("---------\n")

    #     norm_df = normalize_objs(
    #             outcomes.loc[
    #                 scenario_indexes[scen],
    #                 slope_dfs[scen].dropna(axis=0, how="all").dropna(axis=1, how="all").columns,
    #             ],
    #             directions=[directions_dict[i] for i in slope_dfs[scen].columns],
    #         )[0].rename(columns = obj_names).reset_index(drop=True)

    norm_df = (
        outcomes.loc[
            scenario_indexes[scen],
            slope_dfs[scen].dropna(axis=0, how="all").dropna(axis=1, how="all").columns,
        ]
        .rename(columns=obj_names)
        .reset_index(drop=True)
    )

    norm_df["Name"] = "All Solutions"
    for i, solution_index in enumerate(solution_indices):
        norm_df.loc[solution_index, "Name"] = solution_names[i]
        # norm_df = norm_df.append(norm_df.loc[solution_index, :].copy())

    g = sns.pairplot(
        norm_df,
        corner=True,
        kind="reg",
        hue="Name",
        diag_kind="kde",
        plot_kws={"line_kws": {"color": "salmon"}, "scatter_kws": {"s": 100}},
        palette=policy_colors,
    )
    handles = g._legend_data.values()
    labels = g._legend_data.keys()
    g._legend.remove()
    g.fig.legend(handles=handles, labels=labels, bbox_to_anchor=(0.75, 0.90))
    #     for i in range(len(g.axes)-1):
    #         g.axes[i,0].invert_yaxis()
    #         g.axes[i,i].invert_xaxis()
    g.axes[-1, 0].invert_yaxis()
    g.axes[-1, -1].invert_xaxis()
    plt.savefig(f"../plots/resimulation/{scen}_scenario_pairplot.svg")
    plt.show()

# g = sns.pairplot(normalize_objs(outcomes.loc[scenario_indexes["HighD_LowWh"],['egypt_irr', 'egypt_90', 'sudan_irr','ethiopia_hydro']],
#                             directions=["min", "min","min","max"])[0],
#              corner=True, kind="reg", diag_kind= "kde",plot_kws={'line_kws':{'color':'red'}})
# g.axes[3,0].set_xlim((0,1))
# g.axes[3,0].set_ylim((0,1.2))
# Out:
# ---------
# Baseline
# ---------
# ---------
# ExtremeStress
# ---------
# ---------
# CompensatedStress
# ---------
# ---------
# LowDemand
# ---------
# ---------
# HighBlueNile
# ---------
